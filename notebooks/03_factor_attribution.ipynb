# %% [markdown]
# # 03. Factor Attribution
#
# Deep-dive into the Fama-French 3-factor regression: betas, alpha, R², and rolling exposures.

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %matplotlib inline
plt.style.use("seaborn-v0_8")

# %%
from src.pipelines.run_pipeline import run_pipeline
out = run_pipeline(use_warehouse=False)
# Out:
# INFO: ============================================================
# INFO: PORTFOLIO ANALYTICS PIPELINE - 2026-03-17
# INFO: ============================================================
# INFO: [1/10] Loading holdings...
# INFO: Loading holdings from C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\data\samples\portfolio_holdings.csv
# INFO: Loaded 8 holdings rows for 8 tickers
# DEBUG: Tickers: ['AAPL', 'AGG', 'GLD', 'IEFA', 'JNJ', 'MSFT', 'SPY', 'XOM']
# INFO:   -> 8 rows, 8 tickers: ['AAPL', 'AGG', 'GLD', 'IEFA', 'JNJ', 'MSFT', 'SPY', 'XOM']
# INFO: [2/10] Fetching prices from Yahoo Finance...
# INFO: Fetching prices for 8 tickers: ['AAPL', 'AGG', 'GLD', 'IEFA', 'JNJ', 'MSFT', 'SPY', 'XOM']
# INFO: Date range: 2024-01-01 to 2026-03-17
# DEBUG: AAPL: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: AGG: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: GLD: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: IEFA: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: JNJ: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: MSFT: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: SPY: 552 rows from 2024-01-02 to 2026-03-16
# DEBUG: XOM: 552 rows from 2024-01-02 to 2026-03-16
# INFO: Raw prices saved to C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\data\raw\prices_raw.parquet
# INFO: Fetched 4416 price rows for 8 tickers
# INFO: [3/10] Fetching Fama-French factors...
# INFO: Fetching Fama-French daily factors from Kenneth French Data Library
# INFO: Raw factors saved to C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\data\raw\factors_ff_daily.parquet
# INFO: Loaded 522 factor rows from 2024-01-02 to 2026-01-30
# INFO: [4/10] Validating data...
# INFO: Validation: PASSED
# INFO: Validation: PASSED
# INFO: Validation: PASSED
# INFO: [5/10] Skipping warehouse (--no-warehouse)
# INFO: [6/10] Building prices panel + computing returns...
# INFO: Prices panel built: 552 dates x 8 tickers (2024-01-02 to 2026-03-16)
# INFO: Computed simple returns: 551 days x 8 tickers
# INFO: Market values computed for 8 tickers over 552 days
# INFO: Portfolio returns computed: 551 days, mean daily return = 0.0008
# INFO:   -> Portfolio returns: 551 days, total return = 50.12%
# INFO: [7/10] Computing performance metrics...
# INFO: Performance: cum_return=50.12%, ann_return=20.42%, sharpe=1.08, max_dd=-15.10%
# INFO: [8/10] Computing risk metrics...
# DEBUG: Historical VaR(95%, 1d): 0.0117 (1.17% of portfolio)
# DEBUG: Historical CVaR(95%): 0.0191
# INFO: Risk: ann_vol=13.58%, max_dd=-15.10%, VaR95=1.17%, CVaR95=1.91%
# INFO: [9/10] Running Fama-French factor regression...
# INFO: Factor model: alpha=2.48%/yr, beta_mkt=0.754, SMB=-0.141, HML=-0.053, R^2=0.782
# INFO:   -> Style: Defensive all-cap blend portfolio (beta=0.75, alpha=2.48%/yr, R^2=78%)
# INFO: [10/10] Generating charts and report...
# INFO: Generating charts...
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\cumulative_returns.png
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\drawdown.png
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\rolling_volatility.png
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\monthly_returns_heatmap.png
# DEBUG: Historical VaR(95%, 1d): 0.0117 (1.17% of portfolio)
# DEBUG: Historical CVaR(95%): 0.0191
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\return_distribution.png
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\factor_loadings.png
# INFO: Chart saved: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\figures\sector_weights.png
# INFO: Generated 7 charts
# INFO: HTML report generated: C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\reports\portfolio_report_2026-03-17.html
# INFO:
# INFO: ============================================================
# INFO: PIPELINE COMPLETE
# INFO: ============================================================
# INFO:   Cumulative return : 50.12%
# INFO:   Annualized return : 20.42%
# INFO:   Sharpe ratio      : 1.08
# INFO:   Max drawdown      : -15.10%
# INFO:   VaR 95% (1d)      : 1.17%
# INFO:   Factor beta (mkt) : 0.754
# INFO:   Factor R^2        : 0.782
# INFO:   Report            : C:\Users\dipes\Desktop\Projects\portfolio-analytics-reporting\artifacts\reports\portfolio_report_2026-03-17.html
# INFO:   Charts            : 7 saved to artifacts/figures/
# INFO:

# %%
factor_result = out['factor_result']
attribution = out['attribution']

print(attribution['style_summary'])
print()
for comment in attribution['commentary']:
    print('-', comment)
    print()
# Out:
# Defensive all-cap blend portfolio (beta=0.75, alpha=2.48%/yr, R^2=78%)
#
# - The portfolio is moderately defensive (beta=0.75), with lower market sensitivity than the index.
#
# - The size loading (SMB=-0.14) is near zero, indicating no strong cap bias.
#
# - The value loading (HML=-0.05) is near neutral - the portfolio does not strongly favour either value or growth stocks.
#
# - Alpha is not statistically significant (2.48%/yr, p=0.582). Returns are largely explained by factor exposures.
#
# - The 3-factor model explains 78.2% of daily return variation (R^2=0.782). Some idiosyncratic return drivers are not captured by the three-factor model.

# %%
# Factor loadings bar chart
betas = factor_result.get_betas()
colors = ['steelblue' if v >= 0 else 'firebrick' for v in betas.values()]

fig, ax = plt.subplots(figsize=(8, 5))
bars = ax.bar(list(betas.keys()), list(betas.values()), color=colors, width=0.5)
ax.axhline(0, color='black', linewidth=0.8)
for bar, val in zip(bars, betas.values()):
    ax.text(bar.get_x() + bar.get_width()/2, val + (0.02 if val >= 0 else -0.04),
            f'{val:.3f}', ha='center', fontweight='bold')
ax.set_title(f'Factor Betas  (R² = {factor_result.r_squared:.1%})')
ax.set_ylabel('Beta')
plt.tight_layout()
plt.show()

# %%
# Full statsmodels regression summary
print(factor_result.regression_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     169.0
# Date:                Tue, 17 Mar 2026   Prob (F-statistic):           2.40e-76
# Time:                        14:55:02   Log-Likelihood:                 2135.1
# No. Observations:                 521   AIC:                            -4262.
# Df Residuals:                     517   BIC:                            -4245.
# Df Model:                           3
# Covariance Type:                  HC3
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.704e-05      0.000      0.551      0.582      -0.000       0.000
# mkt_rf         0.7543      0.036     21.168      0.000       0.684       0.824
# smb           -0.1408      0.026     -5.321      0.000      -0.193      -0.089
# hml           -0.0528      0.034     -1.576      0.115      -0.119       0.013
# ==============================================================================
# Omnibus:                       31.525   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              110.780
# Skew:                           0.026   Prob(JB):                     8.80e-25
# Kurtosis:                       5.258   Cond. No.                         173.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
# Rolling 63-day market beta
port_returns = out['portfolio_returns']
factors = out['factors'].set_index('date')
factors.index = pd.to_datetime(factors.index).normalize()
port_returns.index = pd.to_datetime(port_returns.index).normalize()

common = port_returns.index.intersection(factors.index)
excess = port_returns.loc[common] - factors.loc[common, 'rf']
mkt = factors.loc[common, 'mkt_rf']

window = 63
rolling_beta = pd.Series(index=excess.index, dtype=float)

for i in range(window, len(excess)):
    y = excess.iloc[i-window:i]
    x = sm.add_constant(mkt.iloc[i-window:i])
    m = sm.OLS(y, x).fit()
    rolling_beta.iloc[i] = m.params['mkt_rf']

fig, ax = plt.subplots(figsize=(14, 4))
rolling_beta.dropna().plot(ax=ax, color='steelblue', title=f'Rolling {window}-day Market Beta')
ax.axhline(1.0, linestyle='--', color='gray', alpha=0.6, label='Beta=1')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Attribution table
attribution['attribution_table']
# Out:
#             Factor   Loading       P-value  Significant (10%)
# 0  Market (Mkt-RF)  0.754264  1.896333e-99               True
# 1       Size (SMB) -0.140821  1.033678e-07               True
# 2      Value (HML) -0.052816  1.150300e-01              False
# 3   Alpha (annual)  0.024754  5.819209e-01              False
